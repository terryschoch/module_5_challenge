# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# - Add your analysis here.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
from scipy.stats import sem
import numpy as np

# Study data files
mouse_metadata_path = "Resources/Mouse_metadata.csv"
study_results_path = "Resources/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
complete_df = pd.merge(study_results, mouse_metadata, how="outer", on=["Mouse ID"])

# Display the data table for preview
complete_df
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        b128          5           45.651331                 0    Capomulin
# 2        b128         10           43.270852                 0    Capomulin
# 3        b128         15           43.784893                 0    Capomulin
# 4        b128         20           42.731552                 0    Capomulin
# ...       ...        ...                 ...               ...          ...
# 1888     m601         25           33.118756                 1    Capomulin
# 1889     m601         30           31.758275                 1    Capomulin
# 1890     m601         35           30.834357                 1    Capomulin
# 1891     m601         40           31.378045                 1    Capomulin
# 1892     m601         45           28.430964                 1    Capomulin
#
#          Sex  Age_months  Weight (g)
# 0     Female           9          22
# 1     Female           9          22
# 2     Female           9          22
# 3     Female           9          22
# 4     Female           9          22
# ...      ...         ...         ...
# 1888    Male          22          17
# 1889    Male          22          17
# 1890    Male          22          17
# 1891    Male          22          17
# 1892    Male          22          17
#
# [1893 rows x 8 columns]

# %%
# Checking the number of mice.
complete_df['Mouse ID'].nunique()
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
findduplicate = complete_df[complete_df.duplicated(subset=['Mouse ID', 'Timepoint'], keep=False)]
duplicate = findduplicate['Mouse ID'].unique()
duplicate
# Out:
# array(['g989'], dtype=object)

# %%
# Optional: Get all the data for the duplicate mouse ID. 
mousedata_df = complete_df[complete_df['Mouse ID'].isin(duplicate)]
mousedata_df
# Out:
#     Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 860     g989          0           45.000000                 0     Propriva
# 861     g989          0           45.000000                 0     Propriva
# 862     g989          5           48.786801                 0     Propriva
# 863     g989          5           47.570392                 0     Propriva
# 864     g989         10           51.745156                 0     Propriva
# 865     g989         10           49.880528                 0     Propriva
# 866     g989         15           51.325852                 1     Propriva
# 867     g989         15           53.442020                 0     Propriva
# 868     g989         20           55.326122                 1     Propriva
# 869     g989         20           54.657650                 1     Propriva
# 870     g989         25           56.045564                 1     Propriva
# 871     g989         30           59.082294                 1     Propriva
# 872     g989         35           62.570880                 2     Propriva
#
#         Sex  Age_months  Weight (g)
# 860  Female          21          26
# 861  Female          21          26
# 862  Female          21          26
# 863  Female          21          26
# 864  Female          21          26
# 865  Female          21          26
# 866  Female          21          26
# 867  Female          21          26
# 868  Female          21          26
# 869  Female          21          26
# 870  Female          21          26
# 871  Female          21          26
# 872  Female          21          26

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
cleaned_df = complete_df[~complete_df['Mouse ID'].isin(duplicate)]
cleaned_df = cleaned_df.drop_duplicates('Mouse ID').reset_index(drop=True)
cleaned_df.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice in the clean DataFrame.
cleaned_df['Mouse ID'].nunique()
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, 
# and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
tumor_mean = complete_df.groupby(['Drug Regimen'])["Tumor Volume (mm3)"].mean()
tumor_med = complete_df.groupby(['Drug Regimen'])["Tumor Volume (mm3)"].median()
tumor_var = complete_df.groupby(['Drug Regimen'])["Tumor Volume (mm3)"].var()
tumor_std = complete_df.groupby(['Drug Regimen'])["Tumor Volume (mm3)"].std()
tumor_sem = complete_df.groupby(['Drug Regimen'])["Tumor Volume (mm3)"].sem()

# Assemble the resulting series into a single summary DataFrame.
tumor_summary_df = pd.DataFrame({"Mean Tumor Volume": tumor_mean,
                                 "Median Tumor Volume": tumor_med,
                                 "Tumor Volume Variance": tumor_var,
                                 "Tumor Volume Std. Dev.": tumor_std,
                                 "Tumor Volume Std. Err.": tumor_sem
                                })

tumor_summary_df
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin                  45.0                 45.0                    0.0
# Ceftamin                   45.0                 45.0                    0.0
# Infubinol                  45.0                 45.0                    0.0
# Ketapril                   45.0                 45.0                    0.0
# Naftisol                   45.0                 45.0                    0.0
# Placebo                    45.0                 45.0                    0.0
# Propriva                   45.0                 45.0                    0.0
# Ramicane                   45.0                 45.0                    0.0
# Stelasyn                   45.0                 45.0                    0.0
# Zoniferol                  45.0                 45.0                    0.0
#
#               Tumor Volume Std. Dev.  Tumor Volume Std. Err.
# Drug Regimen
# Capomulin                        0.0                     0.0
# Ceftamin                         0.0                     0.0
# Infubinol                        0.0                     0.0
# Ketapril                         0.0                     0.0
# Naftisol                         0.0                     0.0
# Placebo                          0.0                     0.0
# Propriva                         0.0                     0.0
# Ramicane                         0.0                     0.0
# Stelasyn                         0.0                     0.0
# Zoniferol                        0.0                     0.0

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, 
# and SEM of the tumor volume for each regimen

# Using the aggregation method, produce the same summary statistics in a single line.
tumor_agg = complete_df.groupby(['Drug Regimen']).agg({'Tumor Volume (mm3)': ['mean', 'median', 'var', 'std', 'sem']})
tumor_agg
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.322552  50.854632  42.351070  6.507770  0.512884
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested 
# for each drug regimen using Pandas.

# Get total number of timepoints for all mice by drug regimen
regimen_data = complete_df['Drug Regimen'].value_counts()

# Configure plot, figsize, title, and axis labels
regimen_bar = regimen_data.plot(kind="bar", facecolor="green", figsize=(6,4),                                
                                xlabel="Drug Regimen",
                                ylabel="Numbe of Mice Tested")

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested 
# for each drug regimen using pyplot.

# Get list for number of mice tested per drug regimen and use index to create drug_regimen list
mice_tested = (complete_df.groupby(['Drug Regimen'])['Timepoint'].count()).sort_values(ascending=False)
drug_regimen = mice_tested.index

# Set x and y labels and orient xticks for readability, plot bar chart. Show chart.
plt.xticks(rotation=90)
plt.xlabel("Drug Regimen")
plt.ylabel("Number of Mice Tested")
plt.bar(drug_regimen, mice_tested, color='g', alpha=0.5, align="center")
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas

# Get total number of male and female mice
gender_data = cleaned_df['Sex'].value_counts()

# Create the pie chart based upon the values above
gender_pie = gender_data.plot(kind="pie", y='Sex', autopct='%1.1f%%')

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

# Get list for gender data and create lists for labels and colours
gender_data_py = cleaned_df['Sex'].value_counts()
labels = gender_data.index
colors = ["cornflowerblue", "orange"]

# Set y label, plot pie chart. Show chart.
plt.ylabel("Sex")
plt.pie(gender_data_py, labels=labels, colors=colors, autopct="%1.1f%%")
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse
maxtimepoint = complete_df.groupby('Mouse ID').agg(Timepoint = ('Timepoint', 'max'),
                                                   Tumor_Volume = ('Tumor Volume (mm3)', 'max')).reset_index()

# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint
complete_df = pd.merge(cleaned_df, maxtimepoint, how="inner", on=["Mouse ID"])
complete_df
# Out:
#     Mouse ID  Timepoint_x  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0       b128            0                45.0                 0    Capomulin
# 1       f932            0                45.0                 0     Ketapril
# 2       g107            0                45.0                 0     Ketapril
# 3       a457            0                45.0                 0     Ketapril
# 4       c819            0                45.0                 0     Ketapril
# ..       ...          ...                 ...               ...          ...
# 243     t565            0                45.0                 0    Capomulin
# 244     i557            0                45.0                 0    Capomulin
# 245     m957            0                45.0                 0    Capomulin
# 246     f966            0                45.0                 0    Capomulin
# 247     m601            0                45.0                 0    Capomulin
#
#         Sex  Age_months  Weight (g)  Timepoint_y  Tumor_Volume
# 0    Female           9          22           45     45.651331
# 1      Male          15          29            0     45.000000
# 2    Female           2          29           35     71.905117
# 3    Female          11          30           10     49.783419
# 4      Male          21          25           40     62.175705
# ..      ...         ...         ...          ...           ...
# 243  Female          20          17           45     46.749006
# 244  Female           1          24           45     47.685963
# 245  Female           3          19           45     46.414518
# 246    Male          16          17           20     45.000000
# 247    Male          22          17           45     45.000000
#
# [248 rows x 10 columns]

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatments = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]

# Create empty list to fill with tumor vol data (for plotting)
tumvoldata = []
tumvoldata2 = []
    
for x in treatments: 
    test = complete_df.iloc[list(complete_df['Drug Regimen'] == x)]
    test2 = test.iloc[:, 9]
    test4 = test.iloc[:, [4, 9]]
    tumvoldata.append(test2)
    tumvoldata2.append(test4)
# print(test2)
# cap = complete_df.iloc[list(complete_df['Drug Regimen'] == "Capomulin")]
# print(test)
# test3 = test['Tumor_Volume']

# print(test)


# test7 = test.groupby('Drug Regimen')
quartilestest = test.groupby('Drug Regimen')['Tumor_Volume'].quantile([.25,.5,.75])
# quartilestest = test.groupby('Drug Regimen')
# qtest = quartilestest['Tumor_Volume'].quantile([.25,.5,.75])
# print(qtest)
# lowerq = qtest[0.25]
# upperq = qtest[0.75]
# iqr = upperq-lowerq
# print(f"The lower quartile of the Tumor Volume is: {lowerq}")
# print(f"The upper quartile of Tumor Volume is: {upperq}")
# print(f"The interquartile range of Tumor Volume is: {iqr}")
# print(f"The median of Tumor Volume is: {quartiles[0.5]} ")

# lower_bound = lowerq - (1.5*iqr)
# upper_bound = upperq + (1.5*iqr)
# print(f"Values below {lower_bound} could be outliers.")
# print(f"Values above {upper_bound} could be outliers.")
# test5 = tumvoldata2[0]
# print(test5)

summary_df = pd.DataFrame({"Capomulin": tumvoldata[0],
                           "Ramicane": tumvoldata[1],
                           "Infubinol": tumvoldata[2],
                           "Ceftamin": tumvoldata[3]
                             })
summary_df.dropna()
summary_df.reset_index(drop=True)
# Out:
#     Capomulin  Ramicane  Infubinol  Ceftamin
# 0   45.651331       NaN        NaN       NaN
# 1         NaN       NaN  45.000000       NaN
# 2         NaN       NaN  72.226731       NaN
# 3         NaN       NaN  46.250112       NaN
# 4         NaN       NaN  57.031862       NaN
# ..        ...       ...        ...       ...
# 95  46.749006       NaN        NaN       NaN
# 96  47.685963       NaN        NaN       NaN
# 97  46.414518       NaN        NaN       NaN
# 98  45.000000       NaN        NaN       NaN
# 99  45.000000       NaN        NaN       NaN
#
# [100 rows x 4 columns]

# %%
quartilestestca = summary_df['Capomulin'].quantile([.25,.5,.75])
quartilestestra = summary_df['Ramicane'].quantile([.25,.5,.75])
quartilestestin = summary_df['Infubinol'].quantile([.25,.5,.75])
quartilestestce = summary_df['Ceftamin'].quantile([.25,.5,.75])
print(quartilestestca, quartilestestra, quartilestestin, quartilestestce)

lowerqca = quartilestestca[0.25]
upperqca = quartilestestca[0.75]
iqrca = upperqca-lowerqca
lowerqra = quartilestestra[0.25]
upperqra = quartilestestra[0.75]
iqrra = upperqra-lowerqra
lowerqin = quartilestestin[0.25]
upperqin = quartilestestin[0.75]
iqrin = upperqin-lowerqin
lowerqce = quartilestestce[0.25]
upperqce = quartilestestce[0.75]
iqrce = upperqce-lowerqce
print(lowerqca, upperqca, iqrca, lowerqra, upperqra, iqrra, lowerqin, upperqin, iqrin, lowerqce, upperqce, iqrce)

lower_boundca = lowerqca - (1.5*iqrca)
upper_boundca = upperqca + (1.5*iqrca)
lower_boundra = lowerqra - (1.5*iqrra)
upper_boundra = upperqra + (1.5*iqrra)
lower_boundin = lowerqin - (1.5*iqrin)
upper_boundin = upperqin + (1.5*iqrin)
lower_boundce = lowerqce - (1.5*iqrce)
upper_boundce = upperqce + (1.5*iqrce)

print(lower_boundca, upper_boundca, lower_boundra, upper_boundra, lower_boundin, upper_boundin, lower_boundce, upper_boundce)
# Out:
# 0.25    45.000000
# 0.50    45.893720
# 0.75    46.749006
# Name: Capomulin, dtype: float64 0.25    45.000000
# 0.50    45.521875
# 0.75    46.343832
# Name: Ramicane, dtype: float64 0.25    54.048608
# 0.50    60.165180
# 0.75    65.525743
# Name: Infubinol, dtype: float64 0.25    48.722078
# 0.50    59.851956
# 0.75    64.299830
# Name: Ceftamin, dtype: float64
# 45.0 46.74900552 1.7490055199999972 45.0 46.34383237 1.3438323700000012 54.04860769 65.52574285 11.477135160000003 48.72207785 64.29983003 15.577752179999997
# 42.376491720000004 49.37251379999999 42.984251445 48.359580925 36.83290494999999 82.74144559000001 25.355449580000002 87.66645829999999

# %%
# # Calculate the IQR and quantitatively determine if there are any potential outliers. 
quartiles = test3.quantile([.25,.5,.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq
print(f"The lower quartile of the Tumor Volume is: {lowerq}")
print(f"The upper quartile of Tumor Volume is: {upperq}")
print(f"The interquartile range of Tumor Volume is: {iqr}")
print(f"The median of Tumor Volume is: {quartiles[0.5]} ")

lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)
print(f"Values below {lower_bound} could be outliers.")
print(f"Values above {upper_bound} could be outliers.")

#     # Locate the rows which contain mice on each drug and get the tumor volumes
    
    
    # add subset 
    
    
    # Determine outliers using upper and lower bounds

# %%
# Put treatments into a list for for loop (and later for plot labels)


# Create empty list to fill with tumor vol data (for plotting)


# Calculate the IQR and quantitatively determine if there are any potential outliers. 

    
    # Locate the rows which contain mice on each drug and get the tumor volumes
    
    
    # add subset 
    
    
    # Determine outliers using upper and lower bounds

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.
# Example outlier plot of reaction times
fig1, ax1 = plt.subplots()
ax1.set_ylabel('Final Tumor Volume (mm3)')
ax1.boxplot(tumvoldata)
plt.xticks(np.arange(5), ['', 'Capomulin','Ramicane', 'Infubinol','Ceftamin'])
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
volume = complete_df.loc['Drug Regimen' == "Capomulin", ['Tumor_Volume']]
time = complete_df.loc['Drug Regimen' == 'Capomulin', ['Timepoint']]

volume_time_line = plt.plot(time, volume, color="blue", label="World Average" )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [60], in <cell line: 2>()
#       1 # Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
# ----> 2 volume = complete_df.loc['Drug Regimen' == "Capomulin", ['Tumor_Volume']]
#       3 time = complete_df.loc['Drug Regimen' == 'Capomulin', ['Timepoint']]
#       5 volume_time_line = plt.plot(time, volume, color="blue", label="World Average" )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:961, in _LocationIndexer.__getitem__(self, key)
#     959     if self._is_scalar_access(key):
#     960         return self.obj._get_value(*key, takeable=self._takeable)
# --> 961     return self._getitem_tuple(key)
#     962 else:
#     963     # we by definition only have the 0th axis
#     964     axis = self.axis or 0
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1140, in _LocIndexer._getitem_tuple(self, tup)
#    1138 with suppress(IndexingError):
#    1139     tup = self._expand_ellipsis(tup)
# -> 1140     return self._getitem_lowerdim(tup)
#    1142 # no multi-index, so validate all of the indexers
#    1143 tup = self._validate_tuple_indexer(tup)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:867, in _LocationIndexer._getitem_lowerdim(self, tup)
#     863 for i, key in enumerate(tup):
#     864     if is_label_like(key):
#     865         # We don't need to check for tuples here because those are
#     866         #  caught by the _is_nested_tuple_indexer check above.
# --> 867         section = self._getitem_axis(key, axis=i)
#     869         # We should never have a scalar section here, because
#     870         #  _getitem_lowerdim is only called after a check for
#     871         #  is_scalar_access, which that would be.
#     872         if section.ndim == self.ndim:
#     873             # we're in the middle of slicing through a MultiIndex
#     874             # revise the key wrt to `section` by inserting an _NS
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1201, in _LocIndexer._getitem_axis(self, key, axis)
#    1198         return self.obj.iloc[tuple(indexer)]
#    1200 # fall thru to straight lookup
# -> 1201 self._validate_key(key, axis)
#    1202 return self._get_label(key, axis=axis)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1011, in _LocIndexer._validate_key(self, key, axis)
#    1001 @doc(_LocationIndexer._validate_key)
#    1002 def _validate_key(self, key, axis: int):
#    1003     # valid for a collection of labels (we check their presence later)
#    1004     # slice of labels (where start-end in labels)
#    1005     # slice of integers (only if in the labels)
#    1006     # boolean not in slice and with boolean index
#    1007     if isinstance(key, bool) and not (
#    1008         is_bool_dtype(self.obj._get_axis(axis))
#    1009         or self.obj._get_axis(axis).dtype.name == "boolean"
#    1010     ):
# -> 1011         raise KeyError(
#    1012             f"{key}: boolean label can not be used without a boolean index"
#    1013         )
#    1015     if isinstance(key, slice) and (
#    1016         isinstance(key.start, bool) or isinstance(key.stop, bool)
#    1017     ):
#    1018         raise TypeError(f"{key}: boolean values can not be used in a slice")
#
# KeyError: 'False: boolean label can not be used without a boolean index'

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
